# %%
Movie-Ratings.csv

# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\flang\\Downloads'

# %%
sns.set_style('darkgrid')

# %%
 df = pd.read_csv('C:\\Users\\flang\\Downloads\\Movie-Ratings.csv')

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.columns=['Film', 'Genre', 'CriticRatings', 'AudienceRatings','Budgetmillion','Year']

# %%
df.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
df.describe()
# Out:
#        CriticRatings  AudienceRatings  Budgetmillion         Year
# count     559.000000       559.000000     559.000000   559.000000
# mean       47.309481        58.744186      50.236136  2009.152057
# std        26.413091        16.826887      48.731817     1.362632
# min         0.000000         0.000000       0.000000  2007.000000
# 25%        25.000000        47.000000      20.000000  2008.000000
# 50%        46.000000        58.000000      35.000000  2009.000000
# 75%        70.000000        72.000000      65.000000  2010.000000
# max        97.000000        96.000000     300.000000  2011.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null object
# Genre              559 non-null object
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Year               559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.Film= df.Film.astype('category')

# %%
df.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null object
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Year               559 non-null int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
df.Genre= df.Genre.astype('category')

# %%
df.Year=df.Year.astype('category')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-f7d5ee1e0232> in <module>()
# ----> 1 df.Year=df.Year.astype('category')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film               559 non-null category
# Genre              559 non-null category
# CriticRatings      559 non-null int64
# AudienceRatings    559 non-null int64
# Budgetmillion      559 non-null int64
# Year               559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
df.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CriticRatings  AudienceRatings  Budgetmillion
# count     559.000000       559.000000     559.000000
# mean       47.309481        58.744186      50.236136
# std        26.413091        16.826887      48.731817
# min         0.000000         0.000000       0.000000
# 25%        25.000000        47.000000      20.000000
# 50%        46.000000        58.000000      35.000000
# 75%        70.000000        72.000000      65.000000
# max        97.000000        96.000000     300.000000

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j= sns.jointplot(data=df, x = 'CriticRatings', y= 'AudienceRatings', size=7)

# %%
j= sns.jointplot(data=df, x = 'CriticRatings', y= 'AudienceRatings',kind= 'hex', size = 9)

# %%
plt.rcParams['figure.figsize']=10,4

# %% [markdown]
# ---

# %% [markdown]
# --------------

# %%
m1=sns.distplot(df.AudienceRatings,bins=15)

# %%
m2=sns.distplot(df.CriticRatings,bins=15)

# %%
n1=plt.hist(df.AudienceRatings, bins=20)

# %%
n2=plt.hist(df.CriticRatings, bins=20)

# %%
df.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    Budgetmillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
df[df.Genre == 'Drama']
# Out:
#                                     Film  Genre  CriticRatings  \
# 10                            88 Minutes  Drama              5
# 11                    A Dangerous Method  Drama             79
# 13                        A Serious Man   Drama             89
# 18                          Albert Nobbs  Drama             53
# 23                       All Good Things  Drama             33
# 26                          An Education  Drama             94
# 27                             Anonymous  Drama             46
# 47                    Black Swan          Drama             88
# 53                             Brothers   Drama             61
# 55                                Buried  Drama             86
# 56                             Burlesque  Drama             36
# 62                            Changeling  Drama             62
# 74                        Country Strong  Drama             20
# 84                             Dear John  Drama             29
# ...

# %%
df[df.Genre == 'Drama'].Budgetmillion
# Out:
# 10      30
# 11      20
# 13       7
# 18       8
# 23      20
# 26       8
# 27      30
# 47      13
# 53      26
# 55       2
# 56      55
# 62      55
# 74      15
# 84      25
# 96      37
# 99      25
# 112     60
# 116     21
# 117      5
# 119     31
# 120     40
# 128      1
# 131     24
# 132     21
# 151     33
# 158     16
# 171      7
# 195     15
# 199     35
# 213     10
#       ...
# 437     13
# 442     20
# 444      2
# 445     20
# 446     40
# 450     65
# 457     40
# 466     45
# 467     11
# 470     60
# 480     39
# 482     32
# 483     68
# 484     50
# 487      0
# 488      4
# 489    150
# 490     16
# 492     25
# 508     20
# 509     10
# 511      2
# 516     25
# 523     26
# 527     70
# 529     66
# 532     38
# 534     21
# 541     15
# 545      2
# Name: Budgetmillion, Length: 101, dtype: int64

# %%
plt.hist(df[df.Genre == 'Drama'].Budgetmillion)
plt.hist(df[df.Genre == 'Action'].Budgetmillion)
plt.hist(df[df.Genre == 'Thriller'].Budgetmillion)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.hist([df[df.Genre == 'Drama'].Budgetmillion,df[df.Genre == 'Action'].Budgetmillion],bins=20,stacked=True)
plt.show()

# %%
for gen in df.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1=list()
mylabel=list()
for gen in df.Genre.cat.categories:
    list1.append(df[df.Genre == gen].Budgetmillion,)
    mylabel.append(gen)
   
h=plt.hist(list1, bins=20,stacked= True,rwidth=1,label=mylabels)
plt.legend()

# %%
sns.set_style('darkgrid')

# %%
list1=list()
mylabels = list()
for gen in df.Genre.cat.categories:
    list1.append(df[df.Genre == gen].Budgetmillion,)
    mylabels.append(gen)
h=plt.hist(list1, bins=20,stacked= True,rwidth=1,label=mylabels)
plt.legend()

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budgetmillion',
#        'Year'],
#       dtype='object')

# %%
import seaborn as sns

# %%
vis1= sns.lmplot(data=df, x ='CriticRatings', y = 'AudienceRatings',fit_reg=False,hue='Genre',size=6,aspect=1)

# %%
plt.rcParams['figure.figsize']=10,4

# %%
k1=sns.kdeplot(df.CriticRatings,df.AudienceRatings, )

# %%
k1=sns.kdeplot(df.CriticRatings,df.AudienceRatings, shade=True,shade_lowest=False )

# %%
k1=sns.kdeplot(df.CriticRatings,df.AudienceRatings, shade=True,shade_lowest=False, cmap='Reds' )

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'Budgetmillion',
#        'Year'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize']=7,5
sns.set_style('dark')

# %%
k1=sns.kdeplot(df.Budgetmillion, df.AudienceRatings)

# %%
k1=sns.kdeplot(df.Budgetmillion, df.AudienceRatings,shade = True,shade_lowest=False,cmap='pink')

# %%
k1=sns.kdeplot(df.Budgetmillion, df.CriticRatings, )

# %%
f,axes=plt.subplots(1,2,figsize=(12,6),sharex=True,sharey=True)
k1=sns.kdeplot(df.Budgetmillion, df.AudienceRatings,ax=axes[0])
k2=sns.kdeplot(df.Budgetmillion, df.CriticRatings,ax=axes[1] )
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
f,axes=plt.subplots(2,2,figsize=(12,6),sharex=True,sharey=True)
k1=sns.kdeplot(df.Budgetmillion, df.AudienceRatings,ax=axes[1,1])
k2=sns.kdeplot(df.Budgetmillion, df.CriticRatings,ax=axes[0,1] )
k3=sns.kdeplot(df.Budgetmillion, df.AudienceRatings,shade = True,shade_lowest=False,cmap='pink',ax=axes[1,0])
k4=sns.kdeplot(df.Budgetmillion,df.AudienceRatings, shade=True,shade_lowest=False, cmap='Reds',ax=axes[0,0] )
k1.set(xlim=(-20,160))
# Out:
# [(-20, 160)]

# %%
w= sns.boxplot(data= df,x='Genre', y='CriticRatings')

# %%
z= sns.violinplot(data= df, x='Genre',y='CriticRatings')

# %%
w= sns.boxplot(data= df[df.Genre == 'Drama'],x='Year', y='CriticRatings')

# %%
z= sns.violinplot(data= df [df.Genre == 'Drama' ], x='Year',y='CriticRatings')

# %%
g= sns.FacetGrid(df, row='Genre', col='Year', hue="Genre")

# %%
plt.scatter(df.CriticRatings, df.AudienceRatings)

# %%
g= sns.FacetGrid(df, row='Genre', col='Year', hue="Genre")
g= g.map(plt.scatter,'CriticRatings', 'AudienceRatings')

# %%
sns.set_style("ticks", {"xtick.major.size": 8, "ytick.major.size": 8})
sns.set_style('dark')

# %%
g= sns.FacetGrid(df, row='Genre', col='Year', hue="Genre")
g= g.map(plt.hist,'Budgetmillion')

# %%
g= sns.FacetGrid(df, row='Genre', col='Year', hue="Genre")
kwd=dict(s=70,linewidth=0.5,adgecolor='black')

g= g.map(plt.scatter,'CriticRatings', 'AudienceRatings')

# %%
g= sns.FacetGrid(df, row='Genre', col='Year', hue="Genre")
kwd=dict(s=70,linewidth=0.5,adgecolor='black')

g= g.map(plt.scatter,'CriticRatings', 'AudienceRatings')
g.set(xlim=(0,100), ylim=(0,100))
for ax in g.axes.flat:
    ax.plot((0,100), (0,100), c='gray', ls='--')
g.add_legend()

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
sns.set_style('darkgrid')

# %%
sns.set_style('darkgrid')
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
f,axes=plt.subplots(2,2,figsize=(12,6),sharex=True,sharey=True)
k1=sns.kdeplot(df.Budgetmillion, df.AudienceRatings,ax=axes[0,0])
k2=sns.kdeplot(df.Budgetmillion, df.CriticRatings,ax=axes[0,1] )
k3= sns.boxplot(data= df[df.Genre == 'Drama'],x='Year', y='CriticRatings',ax=axes[1,1])
k4=sns.kdeplot(df.CriticRatings,df.AudienceRatings, shade=True,shade_lowest=False, cmap='Reds',ax=axes[1,0] )
k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-081bfcc383b1> in <module>()
#       1
#       2 f,axes=plt.subplots(2,2,figsize=(12,6),sharex=True,sharey=True)
# ----> 3 k1=sns.kdeplot(df.Budgetmillion, df.AudienceRatings,ax=axes[0,0])
#       4 k2=sns.kdeplot(df.Budgetmillion, df.CriticRatings,ax=axes[0,1] )
#       5 k3= sns.boxplot(data= df[df.Genre == 'Drama'],x='Year', y='CriticRatings',ax=axes[1,1])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Budgetmillion'

# %%
w= sns.boxplot(data= df[df.Genre == 'Drama'],x='Year', y='CriticRatings')

# %%
f,axes=plt.subplots(2,2,figsize=(12,6),sharex=True,sharey=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-48f68a97e0db> in <module>()
# ----> 1 f,axes=plt.subplots(2,2,figsize=(12,6),sharex=True,sharey=True)
#
# NameError: name 'plt' is not defined
