# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.__version__
# Out:
# '0.22.0'

# %%
df1 = pd.read_csv('C://Users//flang/Downloads//New_York_City_Population_By_Census_Tracts.csv')

# %%
import pandas as pd

# %%
df1
# Out:
#             Borough  Year  FIPS County Code  DCP Borough Code  Census Tract  \
# 0             Bronx  2000                 5                 2           100
# 1             Bronx  2000                 5                 2           200
# 2             Bronx  2000                 5                 2           400
# 3             Bronx  2000                 5                 2          1600
# 4             Bronx  2000                 5                 2          1900
# 5             Bronx  2000                 5                 2          2000
# 6             Bronx  2000                 5                 2          2300
# 7             Bronx  2000                 5                 2          2400
# 8             Bronx  2000                 5                 2          2500
# 9             Bronx  2000                 5                 2          2701
# 10            Bronx  2000                 5                 2          2702
# ...

# %%
df1.head()
# Out:
#   Borough  Year  FIPS County Code  DCP Borough Code  Census Tract  Population
# 0   Bronx  2000                 5                 2           100       12780
# 1   Bronx  2000                 5                 2           200        3545
# 2   Bronx  2000                 5                 2           400        3314
# 3   Bronx  2000                 5                 2          1600        5237
# 4   Bronx  2000                 5                 2          1900        1584

# %%
df = pd.read_csv('C://Users//flang//Downloads//Sacramentorealestatetransactions.csv')

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
df
# Out:
#                               street             city    zip state  beds  \
# 0                       3526 HIGH ST       SACRAMENTO  95838    CA     2
# 1                        51 OMAHA CT       SACRAMENTO  95823    CA     3
# 2                     2796 BRANCH ST       SACRAMENTO  95815    CA     2
# 3                   2805 JANETTE WAY       SACRAMENTO  95815    CA     2
# 4                    6001 MCMAHON DR       SACRAMENTO  95824    CA     2
# 5                 5828 PEPPERMILL CT       SACRAMENTO  95841    CA     3
# 6                6048 OGDEN NASH WAY       SACRAMENTO  95842    CA     3
# 7                      2561 19TH AVE       SACRAMENTO  95820    CA     3
# 8    11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA     2
# 9                       7325 10TH ST        RIO LINDA  95673    CA     3
# 10                  645 MORRISON AVE       SACRAMENTO  95838    CA     3
# 11                     4085 FAWN CIR       SACRAMENTO  95823    CA     3
# ...

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
import  os

# %%
print(os.getcwd())

#working direction
# Out:
# C:\Users\flang

# %%
#numbers of rows
len(df)
# Out:
# 985

# %%
len(df1)
# Out:
# 4336

# %%
len(df.columns)
# Out:
# 12

# %%
len(df1.columns)
# Out:
# 6

# %%
#se columns
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Borough', 'Year', 'FIPS County Code', 'DCP Borough Code',
#        'Census Tract', 'Population'],
#       dtype='object')

# %%
df.head(7)
# Out:
#                 street        city    zip state  beds  baths  sq__ft  \
# 0         3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1          51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2       2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3     2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4      6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
# 5   5828 PEPPERMILL CT  SACRAMENTO  95841    CA     3      1    1122
# 6  6048 OGDEN NASH WAY  SACRAMENTO  95842    CA     3      2    1104
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# ...

# %%
df.tail()
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 985 entries, 0 to 984
# Data columns (total 12 columns):
# street       985 non-null object
# city         985 non-null object
# zip          985 non-null int64
# state        985 non-null object
# beds         985 non-null int64
# baths        985 non-null int64
# sq__ft       985 non-null int64
# type         985 non-null object
# sale_date    985 non-null object
# price        985 non-null int64
# latitude     985 non-null float64
# longitude    985 non-null float64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 92.4+ KB

# %%
df.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599

# %%
df.describe().transpose()
# Out:
#            count           mean            std           min            25%  \
# zip        985.0   95750.697462      85.176072  95603.000000   95660.000000
# beds       985.0       2.911675       1.307932      0.000000       2.000000
# baths      985.0       1.776650       0.895371      0.000000       1.000000
# sq__ft     985.0    1314.916751     853.048243      0.000000     952.000000
# price      985.0  234144.263959  138365.839085   1551.000000  145000.000000
# latitude   985.0      38.607732       0.145433     38.241514      38.482717
# longitude  985.0    -121.355982       0.138278   -121.551704    -121.446127
#
#                      50%            75%            max
# zip         95762.000000   95828.000000   95864.000000
# beds            3.000000       4.000000       8.000000
# baths           2.000000       2.000000       5.000000
# sq__ft       1304.000000    1718.000000    5822.000000
# price      213750.000000  300000.000000  884790.000000
# ...

# %%
#### REnaming columns of a Dataframe

# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users//flang//Downloads//Sacramentorealestatetransactions.csv')

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df[200:205]
# Out:
#                  street            city    zip state  beds  baths  sq__ft  \
# 200  4660 CEDARWOOD WAY      SACRAMENTO  95823    CA     4      2    1310
# 201  9254 HARROGATE WAY       ELK GROVE  95758    CA     2      2    1006
# 202   6716 TAREYTON WAY  CITRUS HEIGHTS  95621    CA     3      2    1104
# 203     2028 ROBERT WAY      SACRAMENTO  95825    CA     2      1     810
# 204  9346 AIZENBERG CIR       ELK GROVE  95624    CA     2      2    1123
#
#             type                     sale_date   price   latitude   longitude
# 200  Residential  Tue May 20 00:00:00 EDT 2008  150000  38.484834 -121.449316
# 201  Residential  Tue May 20 00:00:00 EDT 2008  152000  38.420138 -121.412179
# 202  Residential  Tue May 20 00:00:00 EDT 2008  156000  38.693724 -121.307169
# 203  Residential  Tue May 20 00:00:00 EDT 2008  156000  38.609982 -121.419263
# 204  Residential  Tue May 20 00:00:00 EDT 2008  156000  38.418750 -121.370019

# %%
len(df)
# Out:
# 985

# %%
df[980:]
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
#             type                     sale_date   price   latitude   longitude
# 980  Residential  Thu May 15 00:00:00 EDT 2008  232425  38.457679 -121.359620
# 981  Residential  Thu May 15 00:00:00 EDT 2008  234000  38.499893 -121.458890
# 982  Residential  Thu May 15 00:00:00 EDT 2008  235000  38.708824 -121.256803
# 983  Residential  Thu May 15 00:00:00 EDT 2008  235301  38.417000 -121.397424
# 984  Residential  Thu May 15 00:00:00 EDT 2008  235738  38.655245 -121.075915

# %%
df[:3]
# Out:
#            street        city    zip state  beds  baths  sq__ft         type  \
# 0    3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836  Residential
# 1     51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167  Residential
# 2  2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796  Residential
#
#                       sale_date  price   latitude   longitude
# 0  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839

# %%
df[: : -1].head(10)
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 979     1909 YARNELL WAY        ELK GROVE  95758    CA     3      2    1262
# 978     5601 REXLEIGH DR       SACRAMENTO  95823    CA     4      2    1715
# 977      5 BISHOPGATE CT       SACRAMENTO  95823    CA     4      2    1329
# 976    2400 INVERNESS DR          LINCOLN  95648    CA     3      2    1358
# 975  5024 CHAMBERLIN CIR        ELK GROVE  95757    CA     3      2    1450
#
#             type                     sale_date   price   latitude   longitude
# ...

# %%
df[::200]
# Out:
#                  street        city    zip state  beds  baths  sq__ft  \
# 0          3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 200  4660 CEDARWOOD WAY  SACRAMENTO  95823    CA     4      2    1310
# 400       117 EVCAR WAY   RIO LINDA  95673    CA     3      2    1182
# 600   7 CRYSTALWOOD CIR     LINCOLN  95648    CA     0      0       0
# 800    1214 DAWNWOOD DR        GALT  95632    CA     3      2    1548
#
#             type                     sale_date   price   latitude   longitude
# 0    Residential  Wed May 21 00:00:00 EDT 2008   59222  38.631913 -121.434879
# 200  Residential  Tue May 20 00:00:00 EDT 2008  150000  38.484834 -121.449316
# 400  Residential  Mon May 19 00:00:00 EDT 2008  164000  38.687659 -121.463300
# 600  Residential  Mon May 19 00:00:00 EDT 2008    4897  38.885962 -121.289436
# 800  Residential  Fri May 16 00:00:00 EDT 2008  328370  38.290119 -121.286023

# %%
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
df['street'].head(10)
# Out:
# 0                       3526 HIGH ST
# 1                        51 OMAHA CT
# 2                     2796 BRANCH ST
# 3                   2805 JANETTE WAY
# 4                    6001 MCMAHON DR
# 5                 5828 PEPPERMILL CT
# 6                6048 OGDEN NASH WAY
# 7                      2561 19TH AVE
# 8    11150 TRINITY RIVER DR Unit 114
# 9                       7325 10TH ST
# Name: street, dtype: object

# %%
['street', 'city', 'zip']
# Out:
# ['street', 'city', 'zip']

# %%
df[['street', 'city', 'zip']].head(10)
# Out:
#                             street            city    zip
# 0                     3526 HIGH ST      SACRAMENTO  95838
# 1                      51 OMAHA CT      SACRAMENTO  95823
# 2                   2796 BRANCH ST      SACRAMENTO  95815
# 3                 2805 JANETTE WAY      SACRAMENTO  95815
# 4                  6001 MCMAHON DR      SACRAMENTO  95824
# 5               5828 PEPPERMILL CT      SACRAMENTO  95841
# 6              6048 OGDEN NASH WAY      SACRAMENTO  95842
# 7                    2561 19TH AVE      SACRAMENTO  95820
# 8  11150 TRINITY RIVER DR Unit 114  RANCHO CORDOVA  95670
# 9                     7325 10TH ST       RIO LINDA  95673

# %%
['state','city', 'street''zip', 'beds']
# Out:
# ['state', 'city', 'streetzip', 'beds']

# %%
df[['state','city', 'street','zip', 'beds']].head(5)
# Out:
#   state        city            street    zip  beds
# 0    CA  SACRAMENTO      3526 HIGH ST  95838     2
# 1    CA  SACRAMENTO       51 OMAHA CT  95823     3
# 2    CA  SACRAMENTO    2796 BRANCH ST  95815     2
# 3    CA  SACRAMENTO  2805 JANETTE WAY  95815     2
# 4    CA  SACRAMENTO   6001 MCMAHON DR  95824     2

# %%
df.city.head(5)
# Out:
# 0    SACRAMENTO
# 1    SACRAMENTO
# 2    SACRAMENTO
# 3    SACRAMENTO
# 4    SACRAMENTO
# Name: city, dtype: object

# %%
df.zip.head(6)
# Out:
# 0    95838
# 1    95823
# 2    95815
# 3    95815
# 4    95824
# 5    95841
# Name: zip, dtype: int64

# %%
df[290:297][['street', 'city', 'zip', 'state']]
# Out:
#                 street            city    zip state
# 290      106 FARHAM DR          FOLSOM  95630    CA
# 291    5405 NECTAR CIR       ELK GROVE  95757    CA
# 292      5411 10TH AVE      SACRAMENTO  95820    CA
# 293  3512 RAINSONG CIR  RANCHO CORDOVA  95670    CA
# 294       1106 55TH ST      SACRAMENTO  95819    CA
# 295    411 ILLSLEY WAY          FOLSOM  95630    CA
# 296  796 BUTTERCUP CIR            GALT  95632    CA

# %%
df.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
df.head(2)
# Out:
#          street        city    zip state  beds  baths  sq__ft         type  \
# 0  3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836  Residential
# 1   51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167  Residential
#
#                       sale_date  price   latitude   longitude
# 0  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028

# %%
answ=df.price*df.beds

# %%
answ.head(3)
# Out:
# 0    118444
# 1    204636
# 2    137760
# dtype: int64

# %%
df['Power']=df.price*df.beds

# %%
df.head(5)
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude  \
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768
#
#     Power
# 0  118444
# 1  204636
# 2  137760
# 3  138614
# 4  163800

# %%
df.drop('Power',1).head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df.head(3)
# Out:
#            street        city    zip state  beds  baths  sq__ft         type  \
# 0    3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836  Residential
# 1     51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167  Residential
# 2  2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796  Residential
#
#                       sale_date  price   latitude   longitude   Power
# 0  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879  118444
# 1  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028  204636
# 2  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839  137760

# %%
df=df.drop('Power',1)

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df.price<69308
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# 982    False
# 983    False
# 984    False
# Name: price, Length: 985, dtype: bool

# %%
filter=df.price<69308

# %%
df[filter]
# Out:
#                       street             city    zip state  beds  baths  \
# 0               3526 HIGH ST       SACRAMENTO  95838    CA     2      1
# 1                51 OMAHA CT       SACRAMENTO  95823    CA     3      1
# 2             2796 BRANCH ST       SACRAMENTO  95815    CA     2      1
# 3           2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1
# 158  6272 LONGFORD DR Unit 1   CITRUS HEIGHTS  95621    CA     2      1
# 335          5840 WALERGA RD       SACRAMENTO  95842    CA     2      1
# 336           923 FULTON AVE       SACRAMENTO  95825    CA     1      1
# 337          261 REDONDO AVE       SACRAMENTO  95815    CA     3      1
# 338            4030 BROADWAY       SACRAMENTO  95817    CA     2      1
# 339            3660 22ND AVE       SACRAMENTO  95820    CA     2      1
# 340             3924 HIGH ST       SACRAMENTO  95838    CA     2      1
# 341            4734 14TH AVE       SACRAMENTO  95820    CA     2      1
# ...

# %%
df[df.beds<1]
# Out:
#                                street             city    zip state  beds  \
# 73                      17 SERASPI CT       SACRAMENTO  95834    CA     0
# 89                   2866 KARITSA AVE       SACRAMENTO  95833    CA     0
# 100             12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0
# 121               5337 DUSTY ROSE WAY   RANCHO CORDOVA  95742    CA     0
# 126               2115 SMOKESTACK WAY       SACRAMENTO  95833    CA     0
# 133                8082 LINDA ISLE LN       SACRAMENTO  95831    CA     0
# 147                     9278 DAIRY CT        ELK GROVE  95624    CA     0
# 153                868 HILDEBRAND CIR           FOLSOM  95630    CA     0
# 169                  14788 NATCHEZ CT   RANCHO MURIETA  95683    CA     0
# 192      5201 LAGUNA OAKS DR Unit 126        ELK GROVE  95758    CA     0
# 234         3139 SPOONWOOD WAY Unit 1       SACRAMENTO  95833    CA     0
# 236                   2340 HURLEY WAY       SACRAMENTO  95825    CA     0
# ...

# %%
sub10=df[::10]

# %%
sub10
# Out:
#                            street             city    zip state  beds  baths  \
# 0                    3526 HIGH ST       SACRAMENTO  95838    CA     2      1
# 10               645 MORRISON AVE       SACRAMENTO  95838    CA     3      2
# 20             6118 STONEHAND AVE   CITRUS HEIGHTS  95621    CA     3      2
# 30   5201 LAGUNA OAKS DR Unit 140        ELK GROVE  95758    CA     2      2
# 40   4800 WESTLAKE PKWY Unit 2109       SACRAMENTO  95835    CA     2      2
# 50                   9417 SARA ST        ELK GROVE  95624    CA     3      2
# 60             4844 CLYDEBANK WAY         ANTELOPE  95843    CA     3      2
# 70            8708 MESA BROOK WAY        ELK GROVE  95624    CA     4      2
# 80                    5037 J PKWY       SACRAMENTO  95823    CA     3      2
# 90               6913 RICHEVE WAY       SACRAMENTO  95828    CA     3      1
# 100         12209 CONSERVANCY WAY   RANCHO CORDOVA  95742    CA     0      0
# ...

# %%
sub10.iat[10,2]
# Out:
# 95742
