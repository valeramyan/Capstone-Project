# %%
import seaborn as sns 
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
sns.set_style("darkgrid")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-1b119d21c806> in <module>()
# ----> 1 tips = sns.load_dataset('tips')
#       2 sns.set_style("darkgrid")
#
# TypeError: 'str' object is not callable

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'], kde)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-5e2e06bb834d> in <module>()
# ----> 1 sns.distplot(tips['total_bill'], kde)
#
# NameError: name 'kde' is not defined

# %%
sns.distplot(tips['total_bill'], kde=False,bins=30)

# %%
sns.kdeplot(tips['total_bill'])

# %%
sns.jointplot(data=tips, x = 'total_bill',y='tip')

# %%
sns.jointplot(data= tips, x= 'total_bill', y = 'tip', kind= 'hex')

# %%
sns.jointplot(data= tips, x = 'total_bill', y= 'tip', kind='reg')

# %%
sns.jointplot(data= tips, x = 'total_bill', y= 'tip', kind='kde')

# %%
sns.pairplot(tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(tips, hue='day')

# %%
sns.rugplot(tips['total_bill'])

# %%
# Don't worry about understanding this code!
# It's just for the diagram below
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

#Create dataset
dataset = np.random.randn(25)

# Create another rugplot
sns.rugplot(dataset);

# Set up the x-axis for the plot
x_min = dataset.min() - 2
x_max = dataset.max() + 2

# 100 equally spaced points from x_min to x_max
x_axis = np.linspace(x_min,x_max,100)

# Set up the bandwidth, for info on this:
url = 'http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth'

bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2


# Create an empty kernel list
kernel_list = []

# Plot each basis function
for data_point in dataset:
    
    # Create a kernel for each point and append to list
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis,kernel,color = 'grey',alpha=0.5)

plt.ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# #  Categorical Plots

# %% [markdown]
# ----

# %%
import seaborn as sns
# %matplotlib inline

# %%
tips= sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np

# %% [markdown]
# # Barplot

# %%
sns.barplot(data=tips,x='sex', y='tip',estimator=np.std)

# %%
sns.barplot(data=tips, x = 'sex', y= 'total_bill')

# %%
sns.barplot(data=tips, x = 'sex', y= 'total_bill',estimator = np.std)

# %%
sns.barplot(data= tips, x='day', y='total_bill')

# %%
sns.barplot(data= tips, x='day', y='total_bill', estimator= np.std)

# %% [markdown]
# # countplot

# %%
sns.countplot(data= tips, x= 'sex')

# %%
sns.countplot(data=tips, x='day')

# %%
sns.countplot(data=tips,x='time')

# %% [markdown]
# # Boxplot

# %% [markdown]
# ---

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.boxplot(data=tips, x='day',y='total_bill')

# %%
sns.boxplot(data=tips,x='day',y='total_bill', hue='smoker')

# %%
sns.boxplot(data=tips,x='day',y='tip')

# %%
sns.boxplot(data=tips,x='day',y='tip',hue='sex')

# %% [markdown]
# # Violinplot

# %% [markdown]
# ---

# %%
sns.violinplot(data=tips,x='day',y='total_bill')

# %%
sns.violinplot(data= tips,x='day',y='total_bill',hue='sex')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot(data=tips,x='day',y='tip',hue='sex',split=True)

# %%
sns.violinplot(data=tips,x='size',y='tip',hue='time', split=True)

# %% [markdown]
#  # Stripplot

# %%
sns.stripplot(data=tips,x='day',y='total_bill')

# %%
sns.stripplot(data=tips,x='day',y='total_bill',jitter=True, hue='sex',dodge=True)

# %%
sns.stripplot(data=tips,x='day',y='tip')

# %%
sns.stripplot(data=tips,x='day',y='tip',jitter=True, dodge='time',hue='time')

# %% [markdown]
# # Swarmplot

# %%
sns.swarmplot(data=tips,x='day',y='total_bill')

# %%
sns.swarmplot(data=tips, x='day',y='total_bill',hue='sex',dodge='sex')

# %%
sns.swarmplot(data=tips,x='day',y='total_bill', color='black')
sns.violinplot(data=tips,x='day',y='total_bill')

# %% [markdown]
# # FACTORPLOT

# %%
sns.violinplot(data=tips,x='day',y='total_bill')

# %%
sns.factorplot(data=tips,x='day',y='total_bill',kind='bar',dodge=True)

# %%
sns.factorplot(data=tips,x='day',y='total_bill',kind='swarm')

# %%
sns.factorplot(data=tips,x='day',y='total_bill',jitter=True, hue='sex',dodge=True,kind='strip')

# %% [markdown]
# # Matrix plot

# %% [markdown]
# ---

# %%
import seaborn as sns
# %matplotlib inline

# %%
flights = sns.load_dataset('flights')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-2cc0f6b070ed> in <module>()
# ----> 1 flights = sns.load_dataset('flights')
#
# TypeError: 'str' object is not callable
